# %%
# Alexander  cuenta.py
class Cuenta:
  #este es el método constructor que inicializa
  #a los atributos de una clase
  def __init__(self, valor):
    self.saldo = valor

# %%
#Menu.py
#from Cuenta import
class Menu:
  pass
print("Probando el objeto")
cuenta1 = Cuenta(3000, "Dèbito")
print( cuenta1.saldo)
print( cuenta1.tipo)
cuenta1.depositar(5000)
print("probando el deposito")
print(cuenta1.saldo)
cuenta1.retirar(1200)
print("probando el retiro")
print(cuenta1.saldo)
# Out:
# Probando el objeto
# 3000
# Dèbito
# probando el deposito
# 8000
# probando el retiro
# 6800

# %%
#Cuenta.py
class Cuenta:
  def __init__(self, valor1, valor2):
    self.saldo = valor1
    self.tipo = valor2
  def depositar(self, cantidad):
    self.saldo=self.saldo+cantidad
  def retirar(self, cantidad):
    self.saldo=self.saldo-cantidad

# %%
#Cuenta.py
class Cuenta:
  def __init__(self, valor1, valor2):
    self.saldo = valor1
    self.tipo = valor2
  def retirar(self, cantidad):
    self.saldo=self.saldo-cantidad

# %% [markdown]
# -perador º (punto)
#  objetoº {atrubuto- metodo}
